# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone --recurse-submodules https://github.com/mikel-brostrom/Yolov5_DeepSort_Pytorch.git  # clone repo
# %cd Yolov5_DeepSort_Pytorch
# %pip install -qr requirements.txt  # install dependencies

import torch
from IPython.display import Image, clear_output  # to display images

clear_output()
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 1.9.0+cu102 (Tesla K80)

# %%
# !python track.py --yolo_weights /content/drive/MyDrive/last.pt --source /content/drive/MyDrive/f1.mp4 --save-vid
# Out:
# ...
# 100% 755k/755k [00:00<00:00, 18.8MB/s]
# ...
# 100% 43.9M/43.9M [00:00<00:00, 51.5MB/s]
#
# video 1/1 (1/2031) /content/drive/MyDrive/f1.mp4: 384x640 1 Mercedes, Done. (0.213s)
# video 1/1 (2/2031) /content/drive/MyDrive/f1.mp4: 384x640 1 Mercedes, Done. (0.165s)
# video 1/1 (3/2031) /content/drive/MyDrive/f1.mp4: 384x640 1 Mercedes, Done. (0.147s)
# video 1/1 (4/2031) /content/drive/MyDrive/f1.mp4: 384x640 1 Mercedes, Done. (0.135s)
# video 1/1 (5/2031) /content/drive/MyDrive/f1.mp4: 384x640 1 Mercedes, Done. (0.129s)
# video 1/1 (6/2031) /content/drive/MyDrive/f1.mp4: 384x640 1 Mercedes, Done. (0.132s)
# video 1/1 (7/2031) /content/drive/MyDrive/f1.mp4: 384x640 1 Mercedes, Done. (0.136s)
# video 1/1 (8/2031) /content/drive/MyDrive/f1.mp4: 384x640 1 Mercedes, Done. (0.136s)
# video 1/1 (9/2031) /content/drive/MyDrive/f1.mp4: 384x640 1 Mercedes, Done. (0.135s)
# video 1/1 (10/2031) /content/drive/MyDrive/f1.mp4: 384x640 1 Mercedes, Done. (0.134s)
# ...
